# %% [markdown]
# ## **Network Plot**

# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_edge('A', 'B')
G.add_edge('B', 'C')
G.add_edge('B','D')
G.add_edge('A','D')
G.add_edge('D','D')

nx.draw(G, with_labels=True)
