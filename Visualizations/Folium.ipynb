# %% [markdown]
# # Installation

# %%
pip install folium

# %% [markdown]
# # Creating a Basic Map

# %%
import folium

my_map = folium.Map(location=[40.7128, -74.0060], zoom_start=30)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab9fda6b68fd855f49b22c669d1908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab9fda6b68fd855f49b22c669d1908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dab9fda6b68fd855f49b22c669d1908 = L.map(
#                 &quot;map_6dab9fda6b68fd855f49b22c669d1908&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - **location**: Specifies the center of the map (latitude and longitude).
# - **zoom_start**: Specifies the initial zoom level (default is 10).

# %% [markdown]
# # Adding Markers

# %% [markdown]
# ## Popups
# for displaying additional information when you click on a marker.

# %%
# Add a popup to the marker
marker = folium.Marker([40.7128, -74.0060], popup="Welcome to NYC!")
marker.add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab9fda6b68fd855f49b22c669d1908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab9fda6b68fd855f49b22c669d1908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dab9fda6b68fd855f49b22c669d1908 = L.map(
#                 &quot;map_6dab9fda6b68fd855f49b22c669d1908&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_2970b767be4df8f24b3283f6d2d5a7db = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#         var popup_c6f90366836d7967281cddf508836102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_571ff6a1e4e0853d28cab6fe2a6ff135 = $(`&lt;div id=&quot;html_571ff6a1e4e0853d28cab6fe2a6ff135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome to NYC!&lt;/div&gt;`)[0];
#                 popup_c6f90366836d7967281cddf508836102.setContent(html_571ff6a1e4e0853d28cab6fe2a6ff135);
#
#
#
#         marker_2970b767be4df8f24b3283f6d2d5a7db.bindPopup(popup_c6f90366836d7967281cddf508836102)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Tooltips
# displayed when you hover over a marker.

# %%
# Add a tooltip to the marker
marker = folium.Marker([40.7128, -74.0060], tooltip="Click for info")
marker.add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab9fda6b68fd855f49b22c669d1908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab9fda6b68fd855f49b22c669d1908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dab9fda6b68fd855f49b22c669d1908 = L.map(
#                 &quot;map_6dab9fda6b68fd855f49b22c669d1908&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_2970b767be4df8f24b3283f6d2d5a7db = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#         var popup_c6f90366836d7967281cddf508836102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_571ff6a1e4e0853d28cab6fe2a6ff135 = $(`&lt;div id=&quot;html_571ff6a1e4e0853d28cab6fe2a6ff135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome to NYC!&lt;/div&gt;`)[0];
#                 popup_c6f90366836d7967281cddf508836102.setContent(html_571ff6a1e4e0853d28cab6fe2a6ff135);
#
#
#
#         marker_2970b767be4df8f24b3283f6d2d5a7db.bindPopup(popup_c6f90366836d7967281cddf508836102)
#         ;
#
#
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_ee00f48d69f4b2df91b9185fc0c8e13d = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             marker_ee00f48d69f4b2df91b9185fc0c8e13d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Customizing Markers
# You can customize the markers with different icons and colors:

# %%
marker = folium.Marker(
    [40.7128, -74.0060],
    popup="New York City",
    icon=folium.Icon(color='yellow', icon='cloud')
)
marker.add_to(my_map)

# Display the map
my_map
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11244\824425391.py:4: UserWarning: color argument of Icon should be one of: {'blue', 'darkgreen', 'purple', 'darkred', 'lightblue', 'gray', 'black', 'orange', 'lightgray', 'beige', 'white', 'lightgreen', 'darkpurple', 'lightred', 'green', 'cadetblue', 'darkblue', 'pink', 'red'}.
#   icon=folium.Icon(color='yellow', icon='cloud')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab9fda6b68fd855f49b22c669d1908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab9fda6b68fd855f49b22c669d1908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dab9fda6b68fd855f49b22c669d1908 = L.map(
#                 &quot;map_6dab9fda6b68fd855f49b22c669d1908&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_2970b767be4df8f24b3283f6d2d5a7db = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#         var popup_c6f90366836d7967281cddf508836102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_571ff6a1e4e0853d28cab6fe2a6ff135 = $(`&lt;div id=&quot;html_571ff6a1e4e0853d28cab6fe2a6ff135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome to NYC!&lt;/div&gt;`)[0];
#                 popup_c6f90366836d7967281cddf508836102.setContent(html_571ff6a1e4e0853d28cab6fe2a6ff135);
#
#
#
#         marker_2970b767be4df8f24b3283f6d2d5a7db.bindPopup(popup_c6f90366836d7967281cddf508836102)
#         ;
#
#
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_ee00f48d69f4b2df91b9185fc0c8e13d = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             marker_ee00f48d69f4b2df91b9185fc0c8e13d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_d45863f51d3537667002f52037ff50d7 = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var icon_2cf99fdd0a48aee13dc887c58817ac27 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;yellow&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d45863f51d3537667002f52037ff50d7.setIcon(icon_2cf99fdd0a48aee13dc887c58817ac27);
#
#
#         var popup_e7e838d6b30d97cb0fa1af17b83942c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_8513da12229bdc6c61009359b952670d = $(`&lt;div id=&quot;html_8513da12229bdc6c61009359b952670d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York City&lt;/div&gt;`)[0];
#                 popup_e7e838d6b30d97cb0fa1af17b83942c0.setContent(html_8513da12229bdc6c61009359b952670d);
#
#
#
#         marker_d45863f51d3537667002f52037ff50d7.bindPopup(popup_e7e838d6b30d97cb0fa1af17b83942c0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Customizing the Map

# %% [markdown]
# ## Tile Layers
# **predefined tile layers**:
# - 'OpenStreetMap': Default map tiles.
# - 'Stamen Terrain': Provides a shaded relief map.
# - 'Stamen Toner': Black and white map.
# - 'CartoDB positron': A minimalistic and light design.

# %%
# Add a tile layer
folium.TileLayer('CartoDB positron').add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dab9fda6b68fd855f49b22c669d1908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dab9fda6b68fd855f49b22c669d1908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dab9fda6b68fd855f49b22c669d1908 = L.map(
#                 &quot;map_6dab9fda6b68fd855f49b22c669d1908&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 30,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_2970b767be4df8f24b3283f6d2d5a7db = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#         var popup_c6f90366836d7967281cddf508836102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_571ff6a1e4e0853d28cab6fe2a6ff135 = $(`&lt;div id=&quot;html_571ff6a1e4e0853d28cab6fe2a6ff135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Welcome to NYC!&lt;/div&gt;`)[0];
#                 popup_c6f90366836d7967281cddf508836102.setContent(html_571ff6a1e4e0853d28cab6fe2a6ff135);
#
#
#
#         marker_2970b767be4df8f24b3283f6d2d5a7db.bindPopup(popup_c6f90366836d7967281cddf508836102)
#         ;
#
#
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_ee00f48d69f4b2df91b9185fc0c8e13d = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             marker_ee00f48d69f4b2df91b9185fc0c8e13d.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var marker_d45863f51d3537667002f52037ff50d7 = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var icon_2cf99fdd0a48aee13dc887c58817ac27 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;yellow&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d45863f51d3537667002f52037ff50d7.setIcon(icon_2cf99fdd0a48aee13dc887c58817ac27);
#
#
#         var popup_e7e838d6b30d97cb0fa1af17b83942c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_8513da12229bdc6c61009359b952670d = $(`&lt;div id=&quot;html_8513da12229bdc6c61009359b952670d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York City&lt;/div&gt;`)[0];
#                 popup_e7e838d6b30d97cb0fa1af17b83942c0.setContent(html_8513da12229bdc6c61009359b952670d);
#
#
#
#         marker_d45863f51d3537667002f52037ff50d7.bindPopup(popup_e7e838d6b30d97cb0fa1af17b83942c0)
#         ;
#
#
#
#
#             tile_layer_bfb99a7228fe0ed77ccf7aa3bf83b471.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
#
#             var tile_layer_49da89099aaad12bfdb88c7a16c78f59 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49da89099aaad12bfdb88c7a16c78f59.addTo(map_6dab9fda6b68fd855f49b22c669d1908);
#
# &

# %% [markdown]
# ## Marker Cluster
# **MarkerCluster** to group nearby markers together.

# %%
from folium.plugins import MarkerCluster

# Create a map
my_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Create a MarkerCluster object
marker_cluster = MarkerCluster().add_to(my_map)

# Add markers to the cluster
for i in range(10):
    folium.Marker(
        location=[40.7128 + i * 0.01, -74.0060],
        popup=f"Marker {i+1}"
    ).add_to(marker_cluster)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_786b4ad37d2523a9780682f1579865f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_786b4ad37d2523a9780682f1579865f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_786b4ad37d2523a9780682f1579865f9 = L.map(
#                 &quot;map_786b4ad37d2523a9780682f1579865f9&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a079aede99cb5ab44a31fb1af725935 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a079aede99cb5ab44a31fb1af725935.addTo(map_786b4ad37d2523a9780682f1579865f9);
#
#
#             var marker_cluster_bcf6ac1712fff3502040a9d02befd38a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_085d5869fe6aea1ce8540d288f2e7260 = L.marker(
#                 [40.7128, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_bcf6ac1712fff3502040a9d02befd38a);
#
#
#         var popup_7733c84d8211c89cdaa5cf924280714e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_e5d8ea19ecc8ed0139153640c51f3029 = $(`&lt;div id=&quot;html_e5d8ea19ecc8ed0139153640c51f3029&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7733c84d8211c89cdaa5cf924280714e.setContent(html_e5d8ea19ecc8ed0139153640c51f3029);
#
#
#
#         marker_085d5869fe6aea1ce8540d288f2e7260.bindPopup(popup_7733c84d8211c89cdaa5cf924280714e)
#         ;
#
#
#
#
#             var marker_edc43fc6c3f8598ae6207ea5911ebaad = L.marker(
#                 [40.7228, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_bcf6ac1712fff3502040a9d02befd38a);
#
#
#         var popup_d09a25fc9be17814b8c1a5849368480e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_0824e99527952f4b54fa090027e8b22e = $(`&lt;div id=&quot;html_0824e99527952f4b54fa090027e8b22e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d09a25fc9be17814b8c1a5849368480e.setContent(html_0824e99527952f4b54fa090027e8b22e);
#
#
#
#         marker_edc43fc6c3f8598ae6207ea5911ebaad.bindPopup(popup_d09a25fc9be17814b8c1a5849368480e)
#         ;
#
#
#
#
#             var marker_05e6ba6acdcb69702fe6f2a0325b0aaa = L.marker(
#                 [40.732800000000005, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_bcf6ac1712fff3502040a9d02befd38a);
#
#
#         var popup_db13f52718ebd01cbadfc8f2e5e0e9be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_4f6b3fcebf8eb99642cf8d75d789463f = $(`&lt;div id=&quot;html_4f6b3fcebf8eb99642cf8d75d789463f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_db13f52718ebd01cbadfc8f2e5e0e9be.setContent(html_4f6b3fcebf8eb99642cf8d75d789463f);
#
#
#
#         marker_05e6ba6acdcb69702fe6f2a0325b0aaa.bindPopup(popup_db13f52718ebd01cbadfc8f2e5e0e9be)
#         ;
#
#
#
#
#             var marker_e5b1462751d19ecf0bb8e19e9c8f671e = L.marker(
#                 [40.7428, -74.006],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(marker_cluster_bcf6ac1712fff3502040a9d02befd38a);
#
#
#         var popup_3a5d5cb0a8aafd27ab83bc5e11a702f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
#   &quot;autoClose&quot;: null,
#   &quot;closeOnClick&quot;: null,
# });
#
#
#
#                 var html_d92307aa93e3b5a1e6ffc55c74962107 = $(`&lt;div id=&quot;html_d92307aa93e3b5a1e6ffc55c74962107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3a5d5cb0a8aafd27ab83bc5e11a70

# %% [markdown]
# ## Handling GeoJSON Data
# GeoJSON is a widely-used format for encoding geographic data. Folium can handle GeoJSON files, displaying them as layers on your map.

# %%
import json

# Load GeoJSON data
with open('your_geojson_file.geojson') as f:
    geojson_data = json.load(f)

# Create a map
my_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Add GeoJSON data as a layer
folium.GeoJson(geojson_data).add_to(my_map)

# Display the map
my_map

# %% [markdown]
# # Choropleth Maps
# Choropleth maps display regions that are color-coded based on a data attribute. You can create choropleth maps using Folium by passing GeoJSON data and associated data values.

# %%
import folium

# Sample GeoJSON data
geojson_data = {
    "type": "FeatureCollection",
    "features": [
        {"type": "Feature", "geometry": {"type": "Polygon", "coordinates": [[[ -74.01, 40.71], [-74.02, 40.71], [-74.02, 40.70], [-74.01, 40.70], [-74.01, 40.71]]] }, "properties": {"name": "Region 1", "value": 10}},
        {"type": "Feature", "geometry": {"type": "Polygon", "coordinates": [[[ -74.02, 40.71], [-74.03, 40.71], [-74.03, 40.70], [-74.02, 40.70], [-74.02, 40.71]]] }, "properties": {"name": "Region 2", "value": 20}},
    ]
}

# Create a map centered on a location
my_map = folium.Map(location=[40.7128, -74.0060], zoom_start=12)

# Data to be linked to the GeoJSON regions
region_data = {
    "Region 1": 10,
    "Region 2": 20
}

# Add a choropleth layer with the corrected data
folium.Choropleth(
    geo_data=geojson_data,
    name="choropleth",
    data=region_data,  # Data that corresponds to the region names
    key_on="feature.properties.name",  # Ensure this matches the 'name' property in the GeoJSON
    fill_color="YlGnBu",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Value",
).add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbbafd5069632d10ff024511c9a9ed75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbbafd5069632d10ff024511c9a9ed75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbbafd5069632d10ff024511c9a9ed75 = L.map(
#                 &quot;map_dbbafd5069632d10ff024511c9a9ed75&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_299be634db656dc774b23a2a0cfd4349 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_299be634db656dc774b23a2a0cfd4349.addTo(map_dbbafd5069632d10ff024511c9a9ed75);
#
#
#             var choropleth_c8349a6e65cbb44826fdd41f8a646ab2 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_f12a0a51681f4871086227ceaf42147f_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Region 1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f12a0a51681f4871086227ceaf42147f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f12a0a51681f4871086227ceaf42147f = L.geoJson(null, {
#                 onEachFeature: geo_json_f12a0a51681f4871086227ceaf42147f_onEachFeature,
#
#                 style: geo_json_f12a0a51681f4871086227ceaf42147f_styler,
#             ...{
# }
#         });
#
#         function geo_json_f12a0a51681f4871086227ceaf42147f_add (data) {
#             geo_json_f12a0a51681f4871086227ceaf42147f
#                 .addData(data);
#         }
#             geo_json_f12a0a51681f4871086227ceaf42147f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.01, 40.71], [-74.02, 40.71], [-74.02, 40.7], [-74.01, 40.7], [-74.01, 40.71]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Region 1&quot;, &quot;value&quot;: 10}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.02, 40.71], [-74.03, 40.71], [-74.03, 40.7], [-74.02, 40.7], [-74.02, 40.71]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Region 2&quot;, &quot;value&quot;: 20}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_f12a0a51681f4871086227ceaf42147f.addTo(choropleth_c8349a6e65cbb44826fdd41f8a646ab2);
#
#
#     var color_map_404e78b01a83b36a1d8958a3d64916fc = {};
#
#
#     color_map_404e78b01a83b36a1d8958a3d64916fc.color = d3.scale.threshold()
#               .domain([10.0, 10.02004008016032, 10.040080160320642, 10.060120240480963, 10.080160320641282, 10.100200400801603, 10.120240480961924, 10.140280561122244, 10.160320641282565, 10.180360721442886, 10.200400801603207, 10.220440881763526, 10.240480961923847, 10.260521042084168, 10.280561122244489, 10.30060120240481, 10.32064128256513, 10.340681362725451, 10.360721442885772, 10.380761523046091, 10.400801603206412, 10.420841683366733, 10.440881763527054, 10.460921843687375, 10.480961923847696, 10.501002004008017, 10.521042084168336, 10.541082164328657, 10.561122244488978, 10.581162324649299, 10.60120240480962, 10.62124248496994, 10.641282565130261, 10.661322645290582, 10.681362725450901, 10.701402805611222, 10.721442885771543, 10.741482965931864, 10.761523046092185, 10.781563126252506, 10.801603206412826, 10.821643286573146, 10.841683366733466, 10.861723446893787, 10.881763527054108, 10.901803607214429, 10.92184368737475, 10.94188376753507, 10.96192384769539, 10.98196392785571, 11.002004008016032, 11.022044088176353, 11.042084168336673, 11.062124248496994, 11.082164328657315, 11.102204408817634, 11.122244488977955, 11.142284569138276, 11.162324649298597, 11.182364729458918, 11.202404809619239, 11.22244488977956, 11.24248496993988, 11.2625250501002, 11.28256513026052, 11.302605210420841, 11.322645290581162, 11.342685370741483, 11.362725450901804, 11.382765531062125, 11.402805611222444, 11.422845691382765, 11.442885771543086, 11.462925851703407, 11.482965931863728, 11.503006012024048, 11.52304609218437, 11.54308617234469, 11.56312625250501, 11.58316633266533, 11.603206412825651, 11.623246492985972, 11.6432865731462

# %% [markdown]
# # Heatmaps
# Heatmaps are used to visualize the intensity of points within a given area. They are useful when you want to show patterns or concentrations in your geospatial data.

# %%
from folium.plugins import HeatMap

# Example data: latitudes and longitudes of points
locations = [
    [40.7128, -74.0060],
    [40.8, -74.0070],
    [45.9, -74.0080],
    [40.10, -74.0090],
]

# Create a map
my_map = folium.Map(location=[40.7128, -74.0060], zoom_start=35)

# Add HeatMap layer
HeatMap(locations).add_to(my_map)

# Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e40997ad8679567a1fbd5f83993439d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e40997ad8679567a1fbd5f83993439d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e40997ad8679567a1fbd5f83993439d6 = L.map(
#                 &quot;map_e40997ad8679567a1fbd5f83993439d6&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 35,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10e803f4ac2498448dd0fb3340f6c738 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10e803f4ac2498448dd0fb3340f6c738.addTo(map_e40997ad8679567a1fbd5f83993439d6);
#
#
#             var heat_map_76fb8c51d58fd2ab1026b238e7b9e94f = L.heatLayer(
#                 [[40.7128, -74.006], [40.8, -74.007], [45.9, -74.008], [40.1, -74.009]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
#   &quot;gradient&quot;: null,
# }
#             );
#
#
#             heat_map_76fb8c51d58fd2ab1026b238e7b9e94f.addTo(map_e40997ad8679567a1fbd5f83993439d6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
